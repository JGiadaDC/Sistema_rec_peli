# %%
#importamos pandas, json, ast y datetime

import pandas as pd
import ast
import json
import datetime

# %% [markdown]
# Abrimos el csv y
# sacamos el head para entender como es estructurado,
# vemos que hay datos anidados, valores nulos y columnas inecesarias

# %%
movie = pd.read_csv('movies_dataset.csv')
movie.head(2)
# Out:
# C:\Users\giada\AppData\Local\Temp\ipykernel_1288\673033719.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie = pd.read_csv('movies_dataset.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                homepage    id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story   862  tt0114709                en
# 1                                   NaN  8844  tt0113497                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# ...

# %%
# comprobamos los valores nulos
movie.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
# Comprobamos los tipos de datos:
movie.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
'''Necesitamos hacer unos cambios:
budget es object, hay que cambiarlo a float (para luego hacer la division con revenue);
release_date es un object, y tenemos que cambiarlo a datetime;
'''

movie['budget'] = pd.to_numeric(movie['budget'], errors='coerce')

movie['release_date'] = pd.to_datetime(movie['release_date'], errors='coerce')

# Comprobamos si los cambios se han actuado
movie.dtypes
# Out:
# adult                            object
# belongs_to_collection            object
# budget                          float64
# genres                           object
# homepage                         object
# id                               object
# imdb_id                          object
# original_language                object
# original_title                   object
# overview                         object
# popularity                       object
# poster_path                      object
# production_companies             object
# production_countries             object
# release_date             datetime64[ns]
# revenue                         float64
# runtime                         float64
# spoken_languages                 object
# status                           object
# tagline                          object
# title                            object
# video                            object
# vote_average                    float64
# ...

# %% [markdown]
# Eliminar los nulos de 'release_date'

# %%
movie = movie.dropna(subset='release_date')

# %% [markdown]
# De haber fechas, deberán tener el formato AAAA-mm-dd, además deberán crear la columna release_year donde extraerán el año de la fecha de estreno.

# %%
movie['release_year']= movie['release_date'].dt.year

movie.dtypes

#podemos ver que el tipo de dato del anio es un float. Lo queremos cambiar a int

movie['release_year'] = pd.to_numeric(movie['release_year'], errors='coerce')
movie.dtypes
# Out:
# adult                            object
# belongs_to_collection            object
# budget                          float64
# genres                           object
# homepage                         object
# id                               object
# imdb_id                          object
# original_language                object
# original_title                   object
# overview                         object
# popularity                       object
# poster_path                      object
# production_companies             object
# production_countries             object
# release_date             datetime64[ns]
# revenue                         float64
# runtime                         float64
# spoken_languages                 object
# status                           object
# tagline                          object
# title                            object
# video                            object
# vote_average                    float64
# ...

# %% [markdown]
# Eliminar columnas inecesarias como video, imdb_id, adult, original_title, poster_path, homepage

# %%
movie = movie.drop(['video','imdb_id','adult','original_title','poster_path','homepage'], axis=1)
movie
# Out:
#                                    belongs_to_collection      budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                    NaN  65000000.0
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3                                                    NaN  16000000.0
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0.0
# ...                                                  ...         ...
# 45460                                                NaN         0.0
# 45462                                                NaN         0.0
# 45463                                                NaN         0.0
# 45464                                                NaN         0.0
# 45465                                                NaN         0.0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %% [markdown]
# Los valores nulos de los campos revenue y budget deben ser rellenados por el número 0

# %%
movie['revenue'].fillna(0, inplace=True)
# Out:
# C:\Users\giada\AppData\Local\Temp\ipykernel_1288\4033206988.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   movie['revenue'].fillna(0, inplace=True)

# %%
#eliminar nulos de budget
movie = movie.dropna(subset='budget')
movie['budget'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Crear la columna con el retorno de inversión, llamada return con los campos revenue y budget,
# dividiendo estas dos últimas revenue / budget,
# Cuando no hay datos disponibles para calcularlo, deberá tomar el valor 0

# %%
movie['return'] = movie['revenue'] / movie['budget']

movie
# Out:
#                                    belongs_to_collection      budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                    NaN  65000000.0
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3                                                    NaN  16000000.0
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0.0
# ...                                                  ...         ...
# 45460                                                NaN         0.0
# 45462                                                NaN         0.0
# 45463                                                NaN         0.0
# 45464                                                NaN         0.0
# 45465                                                NaN         0.0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %%
movie['return'] = movie['return'].fillna(0)

# %%
#comprobamos si hay otros nulos  de interes

movie.isnull().sum()
# Out:
# belongs_to_collection    40888
# budget                       0
# genres                       0
# id                           0
# original_language           11
# overview                   941
# popularity                   0
# production_companies         0
# production_countries         0
# release_date                 0
# revenue                      0
# runtime                    246
# spoken_languages             0
# status                      80
# tagline                  24978
# title                        0
# vote_average                 0
# vote_count                   0
# release_year                 0
# return                       0
# dtype: int64

# %%
#en la columna return hay valores inf == infinitos
#importamos numpy para remplazar los valores con 0

import numpy as np

# %%
movie.replace([np.inf], 0, inplace=True)
movie.dtypes
# Out:
# belongs_to_collection            object
# budget                          float64
# genres                           object
# id                               object
# original_language                object
# overview                         object
# popularity                       object
# production_companies             object
# production_countries             object
# release_date             datetime64[ns]
# revenue                         float64
# runtime                         float64
# spoken_languages                 object
# status                           object
# tagline                          object
# title                            object
# vote_average                    float64
# vote_count                      float64
# release_year                      int32
# return                          float64
# dtype: object

# %%
#eliminamos valores faltantes del df cuando el porcentaje es > a 50%, para tener un df mas eficiente
#El porcentaje lo podemos ver con DataWrangler

movie = movie.dropna(subset='belongs_to_collection')

# %%
movie = movie.drop(['status'], axis = 1)

# %%
#importamos el siguiente csv credit y vusalizamos el head
credit = pd.read_csv('credits.csv')
credit.head(2)
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
#
#                                                 crew    id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...   862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...  8844

# %%
credit['cast'] = credit['cast'].fillna('[]').apply(ast.literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x,list) else[])
credit['cast']
# Out:
# 0        [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1        [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2        [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3        [Whitney Houston, Angela Bassett, Loretta Devi...
# 4        [Steve Martin, Diane Keaton, Martin Short, Kim...
#                                ...
# 45471          [Leila Hatami, Kourosh Tahami, Elham Korda]
# 45472    [Angel Aquino, Perry Dizon, Hazel Orencio, Joe...
# 45473    [Erika Eleniak, Adam Baldwin, Julie du Page, J...
# 45474    [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
# 45475                                                   []
# Name: cast, Length: 45476, dtype: object

# %% [markdown]
# '''Algunos campos, como belongs_to_collection, production_companies y otros (ver diccionario de datos) están anidados, esto es o bien tienen un diccionario o una lista como valores en cada fila,
# ¡deberán desanidarlos para poder y unirlos al dataset de nuevo hacer alguna de las consultas de la API!
# O bien buscar la manera de acceder a esos datos sin desanidarlos.'''

# %%
movie['genres'] = movie['genres'].fillna('[]').apply(ast.literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x,list) else[])

# %%
movie['spoken_languages'] = movie['spoken_languages'].fillna('[]').apply(ast.literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x,list) else[])

# %%
movie['production_companies'] = movie['production_companies'].fillna('[]').apply(ast.literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x,list) else[])

# %%
def extract_json_str(json_str):
    '''la funcion realiza un casteo de str dependiendo
    de la sintaxis al tipo de estructura que se reconozca 
    para manipularse y retornar datos de la pelicula como str
      '''
    # Manejo de errores.
    try:
        # condicion para verificar que la el contexto del str no sea para una lista vacia.
            # Usar el modulo ast para castear la el tipo a la estructura deseada.
        list_ = ast.literal_eval(json_str)
            # For para iterar la lista y encontrar el director entre el crew.
        return list_['name']
            # Retornar NoData si es una lista vacia.
            
    except:
        # Retornar NoData si es un valor nulo o existe otro tipo de error.
        return'NoData'

# %%
movie['belongs_to_collection'] = movie['belongs_to_collection'].apply(extract_json_str)

# %%
def extract_director(director):
    '''la funcion realiza un casteo de str dependiendo
    de la sintaxis al tipo de estructura que se reconozca 
    para manipularse y retornar datos de la pelicula como str
      '''
    # Manejo de errores.
    try:
        # condicion para verificar que la el contexto del str no sea para una lista vacia.
        if director != '[]':
            # Usar el modulo ast para castear la el tipo a la estructura deseada.
            list_ = ast.literal_eval(director)
            # For para iterar la lista y encontrar el director entre el crew.
            for i in list_:
                if i['job'] == 'Director':
                    return i['name']
                else:
                    continue
        else:
            # Retornar NoData si es una lista vacia.
            return 'NoData'
    except:
        # Retornar NoData si es un valor nulo o existe otro tipo de error.
        return'NoData'

# %%
credit['director'] = credit['crew'].apply(extract_director)

# %%
credit.pop('crew')
credit
# Out:
#                                                     cast      id  \
# 0      [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...     862
# 1      [Robin Williams, Jonathan Hyde, Kirsten Dunst,...    8844
# 2      [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...   15602
# 3      [Whitney Houston, Angela Bassett, Loretta Devi...   31357
# 4      [Steve Martin, Diane Keaton, Martin Short, Kim...   11862
# ...                                                  ...     ...
# 45471        [Leila Hatami, Kourosh Tahami, Elham Korda]  439050
# 45472  [Angel Aquino, Perry Dizon, Hazel Orencio, Joe...  111109
# 45473  [Erika Eleniak, Adam Baldwin, Julie du Page, J...   67758
# 45474  [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...  227506
# 45475                                                 []  461257
#
#                director
# 0         John Lasseter
# 1          Joe Johnston
# 2         Howard Deutch
# 3       Forest Whitaker
# 4         Charles Shyer
# ...                 ...
# ...

# %%
movie.pop('budget')
movie.pop('tagline')
movie.pop('runtime')
# Out:
# 0         81.0
# 2        101.0
# 4        106.0
# 9        130.0
# 12        78.0
#          ...
# 45355     95.0
# 45358     88.0
# 45369     89.0
# 45371      0.0
# 45382     88.0
# Name: runtime, Length: 4488, dtype: float64

# %%
#Queremos juntar los dos csv usando merge, Verificamos los campos
print(credit.dtypes)
print(movie.dtypes)
# Out:
# cast        object
# id           int64
# director    object
# dtype: object
# belongs_to_collection            object
# genres                           object
# id                               object
# original_language                object
# overview                         object
# popularity                       object
# production_companies             object
# production_countries             object
# release_date             datetime64[ns]
# revenue                         float64
# spoken_languages                 object
# title                            object
# vote_average                    float64
# vote_count                      float64
# release_year                      int32
# return                          float64
# dtype: object

# %%
# el punto de juncion serà el id,  pero tenemos que cambiarlo de object a int(en el csv de movie)

movie['id'] = pd.to_numeric(movie['id'])

# %%
#ahora con merge juntamos

movie = movie.merge(credit, on='id')

movie.head(2)

#podemos ver que los csv se han unido correctamente
# Out:
#        belongs_to_collection                       genres     id  \
# 0       Toy Story Collection  [Animation, Comedy, Family]    862
# 1  Grumpy Old Men Collection            [Romance, Comedy]  15602
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  A family wedding reignites the ancient feud be...
#
#   popularity            production_companies  \
# 0  21.946943       [Pixar Animation Studios]
# 1    11.7129  [Warner Bros., Lancaster Gate]
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
#
#        revenue spoken_languages             title  vote_average  vote_count  \
# 0  373554033.0        [English]         Toy Story           7.7      5415.0
# ...

# %%
movie.pop('id')
# Out:
# 0          862
# 1        15602
# 2        11862
# 3          710
# 4        21032
#          ...
# 4492     24568
# 4493     19307
# 4494     21251
# 4495    460135
# 4496    182030
# Name: id, Length: 4497, dtype: int64

# %%
movie.pop('production_countries')
# Out:
# 0       [{'iso_3166_1': 'US', 'name': 'United States o...
# 1       [{'iso_3166_1': 'US', 'name': 'United States o...
# 2       [{'iso_3166_1': 'US', 'name': 'United States o...
# 3       [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# 4       [{'iso_3166_1': 'US', 'name': 'United States o...
#                               ...
# 4492     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 4493     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 4494     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 4495    [{'iso_3166_1': 'US', 'name': 'United States o...
# 4496                                                   []
# Name: production_countries, Length: 4497, dtype: object

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk

# Descargar los recursos necesarios de nltk
nltk.download('punkt')
nltk.download('stopwords')



#'overview' es una columna con texto descriptivo de las películas
def normalize_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r'\d+', '', text)  # Eliminar dígitos
    text = re.sub(r'\s+', ' ', text).strip()  # Eliminar espacios en blanco adicionales
    return text

# Tokenización y eliminación de stopwords
stop_words = set(stopwords.words('spanish'))

def tokenize_text(text):
    words = word_tokenize(text)  # Tokenización
    words = [word for word in words if word.isalpha() and word not in stop_words]  # Eliminar stopwords y no alfabéticos
    return words
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\giada\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\giada\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Aplica la normalización y tokenización
movie['overview'] = movie['overview'].apply(normalize_text)
movie['tokens_overview'] = movie['overview'].apply(tokenize_text)
# Mostrar el resultado
movie.head()
# Out:
#             belongs_to_collection                          genres  \
# 0            Toy Story Collection     [Animation, Comedy, Family]
# 1       Grumpy Old Men Collection               [Romance, Comedy]
# 2  Father of the Bride Collection                        [Comedy]
# 3           James Bond Collection   [Adventure, Action, Thriller]
# 4                Balto Collection  [Family, Animation, Adventure]
#
#   original_language                                           overview  \
# 0                en  led by woody, andy's toys live happily in his ...
# 1                en  a family wedding reignites the ancient feud be...
# 2                en  just when george banks has recovered from his ...
# 3                en  james bond must unmask the mysterious head of ...
# 4                en  an outcast half-wolf risks his life to prevent...
#
#   popularity                               production_companies release_date  \
# ...

# %%
#covertimos el dataframe csv

movie.to_csv('clean_movies.csv', encoding = 'utf-8', index=False)

# %%
credit.to_csv('clean_credit.csv', encoding= 'utf-8', index=False)
